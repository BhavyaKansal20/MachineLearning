# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/Users/bhavyakansal/AI/Social_Network_Ads.csv")

# %%
dataset.head(10)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
# 5   27            58000          0
# 6   27            84000          0
# 7   32           150000          1
# 8   25            33000          0
# 9   35            65000          0

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
x = dataset.iloc[:,:-1]
y = dataset["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train ,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 88.75

# %%
lr.predict([[47,49000]])
# Out:
# /opt/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from sklearn.metrics import confusion_matrix , precision_score , recall_score , f1_score

# %%
cf = confusion_matrix(y_test , lr.predict(x_test))

# %%
sns.heatmap(cf , annot=True)
plt.show()

# %% [markdown]
# # UnderSampling

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
ru = RandomUnderSampler()
ru_x , ru_y = ru.fit_resample(x,y)

# %%
ru_x
# Out:
#      Age  EstimatedSalary
# 267   37            74000
# 89    35            50000
# 181   31            71000
# 155   31            15000
# 186   20            82000
# ..   ...              ...
# 393   60            42000
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 399   49            36000
#
# [286 rows x 2 columns]

# %%
ru_y.value_counts()
# Out:
# Purchased
# 0    143
# 1    143
# Name: count, dtype: int64

# %%
x_train2 , x_test2 , y_train2 ,y_test2 = train_test_split(ru_x , ru_y , test_size=0.2,random_state=42)

# %%
lr2 = LogisticRegression()
lr2.fit(x_train2 , y_train2)
# Out:
# LogisticRegression()

# %%
lr2.score(x_test2 , y_test2)*100
# Out:
# 84.48275862068965

# %%
lr2.predict([[45,26000]])
# Out:
# /opt/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
cf2 = confusion_matrix(y_test2 , lr.predict(x_test2))

# %%
sns.heatmap(cf2 , annot=True)
plt.show()

# %% [markdown]
# # OverSampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ro = RandomOverSampler()
ro_x , ro_y = ro.fit_resample(x,y)

# %%
ro_y.value_counts()
# Out:
# Purchased
# 0    257
# 1    257
# Name: count, dtype: int64

# %%
x_train3 , x_test3 , y_train3 ,y_test3 = train_test_split(ro_x , ro_y , test_size=0.2,random_state=42)

# %%
lr3 = LogisticRegression()
lr3.fit(x_train3,y_train3)
# Out:
# LogisticRegression()

# %%
lr3.score(x_test3 , y_test3)*100
# Out:
# 87.37864077669903

# %%
lr.predict([[19,19000]])
# Out:
# /opt/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
lr.predict([[32	,150000	]])
# Out:
# /opt/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

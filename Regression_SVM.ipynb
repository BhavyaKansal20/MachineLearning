# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/Users/bhavyakansal/AI/Datasets/placement.csv")
dataset.head(10)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# 5  7.89     2.99
# 6  6.73     2.60
# 7  6.75     2.48
# 8  6.09     2.31
# 9  8.31     3.51

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa" , y="package" , data=dataset)
plt.show()

# %%
x = dataset[["cgpa"]]
y = dataset["package"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train ,y_test = train_test_split(x , y ,test_size=0.2 , random_state=42)

# %% [markdown]
# # Using Linear Kernel

# %%
from sklearn.svm import SVR

# %%
sv = SVR(kernel="linear")
sv.fit(x_train , y_train)
# Out:
# SVR(kernel='linear')

# %%
sv.score(x_test , y_test)*100
# Out:
# 77.06668029575161

# %%
sv.score(x_train , y_train)*100
# Out:
# 77.45351616879694

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa" , y="package" , data=dataset)
plt.plot(dataset["cgpa"] , sv.predict(x) , color="red")
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa" , y="package" , data=dataset)
plt.scatter(dataset["cgpa"] , sv.predict(x) , color="red")
plt.show()

# %% [markdown]
# # Using Polynomial Kernel

# %%
sv1 = SVR(kernel="poly")
sv1.fit(x_train , y_train)
# Out:
# SVR(kernel='poly')

# %%
sv1.score(x_test , y_test)*100
# Out:
# 72.30726359559661

# %%
sv1.score(x_train , y_train)*100
# Out:
# 73.70560943768257

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa" , y="package" , data=dataset)
plt.plot(dataset["cgpa"] , sv1.predict(x) , color="red")
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa" , y="package" , data=dataset)
plt.scatter(dataset["cgpa"] , sv1.predict(x) , color="red")
plt.show()

# %% [markdown]
# # Using RBF Kernel

# %%
sv2 = SVR(kernel="rbf")
sv2.fit(x_train , y_train)
# Out:
# SVR()

# %%
sv2.score(x_test , y_test)*100
# Out:
# 75.94945442913422

# %%
sv2.score(x_train , y_train)*100
# Out:
# 78.16909319813372

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa" , y="package" , data=dataset)
plt.plot(dataset["cgpa"] , sv2.predict(x) , color="red")
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa" , y="package" , data=dataset)
plt.scatter(dataset["cgpa"] , sv2.predict(x) , color="red")
plt.show()

# %% [markdown]
# # Using Sigmoid Kernel

# %%
sv3 = SVR(kernel="sigmoid")
sv3.fit(x_train , y_train)
# Out:
# SVR(kernel='sigmoid')

# %%
sv3.score(x_test , y_test)*100
# Out:
# -0.12751631607434977

# %%
sv3.score(x_train , y_train)*100
# Out:
# -0.08676628025094946

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa" , y="package" , data=dataset)
plt.plot(dataset["cgpa"] , sv3.predict(x) , color="red")
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa" , y="package" , data=dataset)
plt.scatter(dataset["cgpa"] , sv3.predict(x) , color="red")
plt.show()

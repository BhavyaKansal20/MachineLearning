# %%
'''
1. Ridge Regression, also known as L2 regularization, is an extension to linear Regression that introduces a regularization term to reduce model complexity and help prevent
   overfitting.
2. Ridge Regression is working value/magnitude of coefficients is almost equal to zero.

3. Cost function = loss + 𝜆 Σ||w||^2
'''
